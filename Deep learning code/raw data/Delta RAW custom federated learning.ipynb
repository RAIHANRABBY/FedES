# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix, cohen_kappa_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import matthews_corrcoef
from sklearn.model_selection import train_test_split

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import ExtraTreeClassifier
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import StackingClassifier
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score, cross_val_predict

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv1D, MaxPool1D, Flatten, Dropout,LSTM

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Raw_data = '/content/drive/MyDrive/EEG Signal /Epileptic seizure/data/only data/raw_data.npz'

Theta_data = '/content/drive/MyDrive/EEG Signal /Epileptic seizure/data/feature domain/Delta_frequency.npz'



# RAW = np.load(Raw_data, allow_pickle=True)  # Allow loading pickled object arrays
# X = RAW['X'].astype('float64')
# Y = RAW['Y'].astype('float64')
# group = RAW['Group'].astype('float64')

# %% [markdown]
# This is a good performing model

# %%
# %%capture
# !pip install wandb

# %%
# import wandb

# %%
# !wandb login
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %% [markdown]
# # CNN-LSTM

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, GroupShuffleSplit
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, cohen_kappa_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, BatchNormalization, LSTM, Dropout
from tensorflow.keras.regularizers import l2
from tensorflow.keras.backend import clear_session
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger

class FederatedData:
    def __init__(self, data_path, num_clients, scaler_type='MinMax', test_size=0.2):
        self.data_path = data_path
        self.num_clients = num_clients
        self.scaler_type = scaler_type
        self.test_size = test_size
        self.partitions = []  # Initialize partitions attribute
        self.load_data()
        self.scale_data()
        self.create_partitions()

    def load_data(self):
        try:
            data = np.load(self.data_path, allow_pickle=True)
            self.X = np.moveaxis(data['X'], 1, 2)  # Move axis here
            self.Y = data['Y']
            self.groups = data['Group']  # Assuming 'Group' contains group identifiers
        except KeyError as e:
            raise ValueError(f"Missing expected data field: {e}")
        except FileNotFoundError as e:
            raise ValueError(f"Data file not found: {e}")

    def scale_data(self):
        # Reshape data to 2D array for scaling
        X_reshaped = self.X.reshape(-1, self.X.shape[-1])

        # Select scaler based on input
        if self.scaler_type == 'Standard':
            scaler = StandardScaler()
        elif self.scaler_type == 'MinMax':
            scaler = MinMaxScaler(feature_range=(0, 1))
        else:
            raise ValueError("Unsupported scaler type. Choose either 'Standard' or 'MinMax'.")

        # Fit and transform the data
        scaled_data_reshaped = scaler.fit_transform(X_reshaped)

        # Reshape back to original shape
        self.X = scaled_data_reshaped.reshape(self.X.shape)

    def create_partitions(self):
        gss = GroupShuffleSplit(n_splits=self.num_clients, test_size=self.test_size, random_state=42)
        for train_index, test_index in gss.split(self.X, self.Y, self.groups):
            X_train, X_test = self.X[train_index], self.X[test_index]
            Y_train, Y_test = self.Y[train_index], self.Y[test_index]
            self.partitions.append((X_train, Y_train, X_test, Y_test))
            print(f"Train shape: {X_train.shape}, Test shape: {X_test.shape}")

    def get_training_and_validation_data(self, client_idx):
        if client_idx < 0 or client_idx >= len(self.partitions):
            raise ValueError(f"Invalid client index. Must be between 0 and {len(self.partitions) - 1}.")

        partition_X_train, partition_Y_train, partition_X_test, partition_Y_test = self.partitions[client_idx]
        X_train, X_val, Y_train, Y_val = train_test_split(partition_X_train, partition_Y_train, test_size=0.2, random_state=42)
        return X_train, X_val, Y_train, Y_val, partition_X_test, partition_Y_test

    def get_testing_data(self, client_idx):
        if client_idx < 0 or client_idx >= len(self.partitions):
            raise ValueError(f"Invalid client index. Must be between 0 and {len(self.partitions) - 1}.")

        _, _, partition_X_test, partition_Y_test = self.partitions[client_idx]
        return partition_X_test, partition_Y_test

def build_sequential_model(input_shape):
    clear_session()
    model = Sequential()

    model.add(Conv1D(256, 3, strides=1, activation='relu', padding="same", input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(2, padding="same"))
    model.add(Conv1D(256, 3, strides=1, activation='relu', padding="same"))
    model.add(MaxPooling1D(2, padding="same"))
    model.add(Conv1D(512, 3, strides=1, activation='relu', padding="same"))
    model.add(MaxPooling1D(2, padding="same"))
    model.add(Conv1D(filters=1024, kernel_size=3, strides=1, activation='relu'))
    model.add(Dropout(0.5))
    model.add(LSTM(256, return_sequences=True))
    model.add(LSTM(256, return_sequences=True))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dense(256, activation='relu'))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))

    opt = Adam(learning_rate=0.00009, beta_1=0.9, beta_2=0.999, epsilon=1e-08)
    model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
    model.summary()
    return model

def compute_metrics(y_true, y_pred):
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred)
    kappa = cohen_kappa_score(y_true, y_pred)

    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
    specificity = tn / (tn + fp)
    sensitivity = recall

    return accuracy, precision, recall, f1, sensitivity, specificity, kappa

def federated_learning(data_path):
    federated_data = FederatedData(data_path, num_clients=3, scaler_type='MinMax')
    federated_data.create_partitions()

    # Get the input shape from the data
    input_shape = federated_data.X.shape[1:]
    global_model = build_sequential_model(input_shape)

    num_clients = 3
    local_epochs = 5
    global_optimizer = Adam(learning_rate=0.00009, beta_1=0.9, beta_2=0.999, epsilon=1e-08)

    # Initialize m and v for Adam optimizer
    m = [np.zeros_like(w) for w in global_model.get_weights()]
    v = [np.zeros_like(w) for w in global_model.get_weights()]
    beta1 = 0.9
    beta2 = 0.999
    epsilon = 1e-7
    t = 0

    client_data = []
    for client_idx in range(num_clients):
        x_train, x_val, y_train, y_val, x_test, y_test = federated_data.get_training_and_validation_data(client_idx)
        client_data.append((x_train, x_val, y_train, y_val, x_test, y_test))

    metrics_list = []

    for epoch in range(local_epochs):
        client_models = []

        for client in range(num_clients):
            x_train, x_val, y_train, y_val, x_test, y_test = client_data[client]
            client_model = build_sequential_model(input_shape)
            client_model.set_weights(global_model.get_weights())  # Initialize with global weights
            opt = Adam(learning_rate=0.000009, beta_1=0.9, beta_2=0.999, epsilon=1e-08)
            client_model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])

            # Set up callbacks
            run_name = f"epoch_{epoch}_client_{client}"
            checkpoint_callback = ModelCheckpoint(
                f'/content/drive/MyDrive/EEG Signal /Epileptic seizure/Saved model/Frequency_domain/Delta/best_model_{run_name}.h5',
                monitor='val_accuracy',
                save_best_only=True,
                mode='max'
            )
            csv_logger = CSVLogger(f'/content/drive/MyDrive/EEG Signal /Epileptic seizure/Saved model/Frequency_domain/Delta/training_log_{run_name}.csv', append=True, separator=';')

            history = client_model.fit(x_train, y_train, epochs=100, batch_size=128, validation_data=(x_val, y_val), callbacks=[checkpoint_callback, csv_logger])
            client_models.append(client_model)

            print(history.history)

            # Evaluate client model
            y_pred = (client_model.predict(x_test) > 0.5).astype("int32")
            accuracy, precision, recall, f1, sensitivity, specificity, kappa = compute_metrics(y_test, y_pred)
            metrics_list.append({
                'Client': client,
                'Accuracy': accuracy,
                'Precision': precision,
                'Recall': recall,
                'F1': f1,
                'Sensitivity': sensitivity,
                'Specificity': specificity,
                'Kappa': kappa
            })

        global_weights = global_model.get_weights()
        layer_start_idx = 0
        for layer in global_model.layers:
            layer_weights = []
            layer_biases = []
            num_params = len(layer.get_weights())
            for i in range(num_clients):
                layer_params = client_models[i].get_weights()[layer_start_idx:layer_start_idx + num_params]
                if num_params > 0:
                    layer_weights.append(layer_params[0])
                if num_params > 1:
                    layer_biases.append(layer_params[1])

            if len(layer_weights) > 0:
                averaged_layer_weights = np.mean(layer_weights, axis=0)
                if averaged_layer_weights.shape == global_weights[layer_start_idx].shape:
                    global_weights[layer_start_idx] = averaged_layer_weights
                else:
                    print(f"Warning: Shape mismatch for weights at layer {layer.name}, expected {global_weights[layer_start_idx].shape} but got {averaged_layer_weights.shape}")
            if len(layer_biases) > 0:
                averaged_layer_biases = np.mean(layer_biases, axis=0)
                if averaged_layer_biases.shape == global_weights[layer_start_idx + 1].shape:
                    global_weights[layer_start_idx + 1] = averaged_layer_biases
                else:
                    print(f"Warning: Shape mismatch for biases at layer {layer.name}, expected {global_weights[layer_start_idx + 1].shape} but got {averaged_layer_biases.shape}")

            layer_start_idx += num_params

        # Apply FedOpt (Adam) update to global weights
        t += 1
        for i in range(len(global_weights)):
            g_t = global_weights[i] - global_model.get_weights()[i]  # Gradient
            m[i] = beta1 * m[i] + (1 - beta1) * g_t
            v[i] = beta2 * v[i] + (1 - beta2) * (g_t ** 2)
            m_hat = m[i] / (1 - beta1 ** t)
            v_hat = v[i] / (1 - beta2 ** t)
            global_weights[i] -= global_optimizer.learning_rate * m_hat / (np.sqrt(v_hat) + epsilon)

        global_model.set_weights(global_weights)

    metrics_df = pd.DataFrame(metrics_list)
    return global_model, metrics_df

# Example usage
# data_path = 'path/to/your/data.npz'
# global_model, metrics_df = federated_learning(data_path)
# print(metrics_df)

# %%
global_model, metrics_df = federated_learning(Theta_data)
# Out:
# Train shape: (4640, 19, 29), Test shape: (1194, 19, 29)
# Train shape: (4418, 19, 29), Test shape: (1416, 19, 29)
# Train shape: (4838, 19, 29), Test shape: (996, 19, 29)
# Train shape: (4640, 19, 29), Test shape: (1194, 19, 29)
# Train shape: (4418, 19, 29), Test shape: (1416, 19, 29)
# Train shape: (4838, 19, 29), Test shape: (996, 19, 29)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 19, 256)           22528
#
#  batch_normalization (Batch  (None, 19, 256)           1024
#  Normalization)
#
#  max_pooling1d (MaxPooling1  (None, 10, 256)           0
#  D)
#
#  conv1d_1 (Conv1D)           (None, 10, 256)           196864
#
#  max_pooling1d_1 (MaxPoolin  (None, 5, 256)            0
#  g1D)
#
#  conv1d_2 (Conv1D)           (None, 5, 512)            393728
#
#  max_pooling1d_2 (MaxPoolin  (None, 3, 512)            0
#  g1D)
#
#  conv1d_3 (Conv1D)           (None, 1, 1024)           1573888
#
#  dropout (Dropout)           (None, 1, 1024)           0
#
#  lstm (LSTM)                 (None, 1, 256)            1311744
#
#  lstm_1 (LSTM)               (None, 1, 256)            525312
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 512)               131584
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dense_2 (Dense)             (None, 32)                8224
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 4296257 (16.39 MB)
# Trainable params: 4295745 (16.39 MB)
# Non-trainable params: 512 (2.00 KB)
# _________________________________________________________________
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 19, 256)           22528
#
#  batch_normalization (Batch  (None, 19, 256)           1024
#  Normalization)
#
#  max_pooling1d (MaxPooling1  (None, 10, 256)           0
#  D)
#
#  conv1d_1 (Conv1D)           (None, 10, 256)           196864
#
#  max_pooling1d_1 (MaxPoolin  (None, 5, 256)            0
#  g1D)
#
#  conv1d_2 (Conv1D)           (None, 5, 512)            393728
#
#  max_pooling1d_2 (MaxPoolin  (None, 3, 512)            0
#  g1D)
#
#  conv1d_3 (Conv1D)           (None, 1, 1024)           1573888
#
#  dropout (Dropout)           (None, 1, 1024)           0
#
#  lstm (LSTM)                 (None, 1, 256)            1311744
#
#  lstm_1 (LSTM)               (None, 1, 256)            525312
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 512)               131584
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dense_2 (Dense)             (None, 32)                8224
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 4296257 (16.39 MB)
# Trainable params: 4295745 (16.39 MB)
# Non-trainable params: 512 (2.00 KB)
# _________________________________________________________________
# Epoch 1/100
# 29/29 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.5054
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 29/29 [==============================] - 20s 73ms/step - loss: 0.6931 - accuracy: 0.5054 - val_loss: 0.6931 - val_accuracy: 0.4849
# Epoch 2/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6931 - accuracy: 0.5038 - val_loss: 0.6932 - val_accuracy: 0.4849
# Epoch 3/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6931 - accuracy: 0.5038 - val_loss: 0.6931 - val_accuracy: 0.4849
# Epoch 4/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6930 - accuracy: 0.5038 - val_loss: 0.6931 - val_accuracy: 0.4849
# Epoch 5/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6930 - accuracy: 0.5038 - val_loss: 0.6931 - val_accuracy: 0.4849
# Epoch 6/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6929 - accuracy: 0.5038 - val_loss: 0.6931 - val_accuracy: 0.4849
# Epoch 7/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6928 - accuracy: 0.5038 - val_loss: 0.6931 - val_accuracy: 0.4849
# Epoch 8/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6927 - accuracy: 0.5043 - val_loss: 0.6931 - val_accuracy: 0.4849
# Epoch 9/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6926 - accuracy: 0.5038 - val_loss: 0.6930 - val_accuracy: 0.4849
# Epoch 10/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6924 - accuracy: 0.5038 - val_loss: 0.6930 - val_accuracy: 0.4849
# Epoch 11/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6923 - accuracy: 0.5038 - val_loss: 0.6929 - val_accuracy: 0.4849
# Epoch 12/100
# 29/29 [==============================] - 1s 20ms/step - loss: 0.6921 - accuracy: 0.4997 - val_loss: 0.6927 - val_accuracy: 0.5356
# Epoch 13/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6919 - accuracy: 0.4941 - val_loss: 0.6926 - val_accuracy: 0.5291
# Epoch 14/100
# 29/29 [==============================] - 1s 21ms/step - loss: 0.6917 - accuracy: 0.5016 - val_loss: 0.6925 - val_accuracy: 0.5442
# Epoch 15/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6915 - accuracy: 0.5035 - val_loss: 0.6922 - val_accuracy: 0.5356
# Epoch 16/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6912 - accuracy: 0.5108 - val_loss: 0.6920 - val_accuracy: 0.5442
# Epoch 17/100
# 29/29 [==============================] - 1s 19ms/step - loss: 0.6911 - accuracy: 0.5121 - val_loss: 0.6918 - val_accuracy: 0.5485
# Epoch 18/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6908 - accuracy: 0.5145 - val_loss: 0.6915 - val_accuracy: 0.5485
# Epoch 19/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6907 - accuracy: 0.5175 - val_loss: 0.6912 - val_accuracy: 0.5453
# Epoch 20/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6904 - accuracy: 0.5164 - val_loss: 0.6909 - val_accuracy: 0.5431
# Epoch 21/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6899 - accuracy: 0.5216 - val_loss: 0.6907 - val_accuracy: 0.5399
# Epoch 22/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6896 - accuracy: 0.5251 - val_loss: 0.6903 - val_accuracy: 0.5323
# Epoch 23/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6891 - accuracy: 0.5275 - val_loss: 0.6900 - val_accuracy: 0.5356
# Epoch 24/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6887 - accuracy: 0.5261 - val_loss: 0.6897 - val_accuracy: 0.5216
# Epoch 25/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.6884 - accuracy: 0.5272 - val_loss: 0.6897 - val_accuracy: 0.5237
# Epoch 26/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.6879 - accuracy: 0.5323 - val_loss: 0.6895 - val_accuracy: 0.5226
# Epoch 27/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.6875 - accuracy: 0.5391 - val_loss: 0.6895 - val_accuracy: 0.5259
# Epoch 28/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.6869 - accuracy: 0.5374 - val_loss: 0.6894 - val_accuracy: 0.5226
# Epoch 29/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.6866 - accuracy: 0.5409 - val_loss: 0.6894 - val_accuracy: 0.5323
# Epoch 30/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.6856 - accuracy: 0.5458 - val_loss: 0.6890 - val_accuracy: 0.5312
# Epoch 31/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.6853 - accuracy: 0.5520 - val_loss: 0.6887 - val_accuracy: 0.5388
# Epoch 32/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.6843 - accuracy: 0.5477 - val_loss: 0.6887 - val_accuracy: 0.5302
# Epoch 33/100
# 29/29 [==============================] - 0s 14ms/step - loss: 0.6837 - accuracy: 0.5520 - val_loss: 0.6883 - val_accuracy: 0.5388
# Epoch 34/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6829 - accuracy: 0.5447 - val_loss: 0.6882 - val_accuracy: 0.5409
# Epoch 35/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6816 - accuracy: 0.5517 - val_loss: 0.6880 - val_accuracy: 0.5399
# Epoch 36/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6813 - accuracy: 0.5477 - val_loss: 0.6882 - val_accuracy: 0.5420
# Epoch 37/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6802 - accuracy: 0.5593 - val_loss: 0.6881 - val_accuracy: 0.5442
# Epoch 38/100
# 29/29 [==============================] - 1s 21ms/step - loss: 0.6788 - accuracy: 0.5574 - val_loss: 0.6880 - val_accuracy: 0.5528
# Epoch 39/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6785 - accuracy: 0.5585 - val_loss: 0.6882 - val_accuracy: 0.5453
# Epoch 40/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6771 - accuracy: 0.5598 - val_loss: 0.6891 - val_accuracy: 0.5453
# Epoch 41/100
# 29/29 [==============================] - 1s 20ms/step - loss: 0.6751 - accuracy: 0.5585 - val_loss: 0.6888 - val_accuracy: 0.5560
# Epoch 42/100
# 29/29 [==============================] - 0s 14ms/step - loss: 0.6749 - accuracy: 0.5593 - val_loss: 0.6901 - val_accuracy: 0.5560
# Epoch 43/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6740 - accuracy: 0.5601 - val_loss: 0.6895 - val_accuracy: 0.5550
# Epoch 44/100
# 29/29 [==============================] - 1s 20ms/step - loss: 0.6743 - accuracy: 0.5625 - val_loss: 0.6908 - val_accuracy: 0.5603
# Epoch 45/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6718 - accuracy: 0.5641 - val_loss: 0.6910 - val_accuracy: 0.5506
# Epoch 46/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6718 - accuracy: 0.5652 - val_loss: 0.6914 - val_accuracy: 0.5474
# Epoch 47/100
# 29/29 [==============================] - 0s 11ms/step - loss: 0.6704 - accuracy: 0.5655 - val_loss: 0.6920 - val_accuracy: 0.5528
# Epoch 48/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6687 - accuracy: 0.5787 - val_loss: 0.6924 - val_accuracy: 0.5539
# Epoch 49/100
# 29/29 [==============================] - 1s 21ms/step - loss: 0.6675 - accuracy: 0.5797 - val_loss: 0.6940 - val_accuracy: 0.5657
# Epoch 50/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6674 - accuracy: 0.5760 - val_loss: 0.6952 - val_accuracy: 0.5420
# Epoch 51/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6664 - accuracy: 0.5787 - val_loss: 0.6944 - val_accuracy: 0.5528
# Epoch 52/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6654 - accuracy: 0.5776 - val_loss: 0.6952 - val_accuracy: 0.5528
# Epoch 53/100
# 29/29 [==============================] - 0s 14ms/step - loss: 0.6654 - accuracy: 0.5792 - val_loss: 0.6957 - val_accuracy: 0.5560
# Epoch 54/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6650 - accuracy: 0.5781 - val_loss: 0.6970 - val_accuracy: 0.5560
# Epoch 55/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6638 - accuracy: 0.5832 - val_loss: 0.6960 - val_accuracy: 0.5571
# Epoch 56/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6618 - accuracy: 0.5787 - val_loss: 0.6961 - val_accuracy: 0.5582
# Epoch 57/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6612 - accuracy: 0.5779 - val_loss: 0.6989 - val_accuracy: 0.5485
# Epoch 58/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.6580 - accuracy: 0.5881 - val_loss: 0.6994 - val_accuracy: 0.5539
# Epoch 59/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.6593 - accuracy: 0.5824 - val_loss: 0.6991 - val_accuracy: 0.5625
# Epoch 60/100
# 29/29 [==============================] - 1s 21ms/step - loss: 0.6584 - accuracy: 0.5846 - val_loss: 0.7017 - val_accuracy: 0.5528
# Epoch 61/100
# 29/29 [==============================] - 1s 23ms/step - loss: 0.6553 - accuracy: 0.5902 - val_loss: 0.7033 - val_accuracy: 0.5560
# Epoch 62/100
# 29/29 [==============================] - 1s 19ms/step - loss: 0.6551 - accuracy: 0.5929 - val_loss: 0.7039 - val_accuracy: 0.5571
# Epoch 63/100
# 29/29 [==============================] - 1s 21ms/step - loss: 0.6548 - accuracy: 0.5897 - val_loss: 0.7077 - val_accuracy: 0.5463
# Epoch 64/100
# 29/29 [==============================] - 1s 19ms/step - loss: 0.6546 - accuracy: 0.5932 - val_loss: 0.7054 - val_accuracy: 0.5517
# Epoch 65/100
# 29/29 [==============================] - 1s 22ms/step - loss: 0.6526 - accuracy: 0.5932 - val_loss: 0.7051 - val_accuracy: 0.5517
# Epoch 66/100
# 29/29 [==============================] - 1s 22ms/step - loss: 0.6507 - accuracy: 0.5927 - val_loss: 0.7059 - val_accuracy: 0.5496
# Epoch 67/100
# 29/29 [==============================] - 0s 14ms/step - loss: 0.6515 - accuracy: 0.6032 - val_loss: 0.7066 - val_accuracy: 0.5485
# Epoch 68/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.6493 - accuracy: 0.6008 - val_loss: 0.7124 - val_accuracy: 0.5560
# Epoch 69/100
# 29/29 [==============================] - 0s 16ms/step - loss: 0.6481 - accuracy: 0.6008 - val_loss: 0.7090 - val_accuracy: 0.5550
# Epoch 70/100
# 29/29 [==============================] - 1s 19ms/step - loss: 0.6480 - accuracy: 0.5967 - val_loss: 0.7122 - val_accuracy: 0.5496
# Epoch 71/100
# 29/29 [==============================] - 1s 22ms/step - loss: 0.6473 - accuracy: 0.5991 - val_loss: 0.7157 - val_accuracy: 0.5485
# Epoch 72/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.6498 - accuracy: 0.6010 - val_loss: 0.7117 - val_accuracy: 0.5485
# Epoch 73/100
# 29/29 [==============================] - 0s 15ms/step - loss: 0.6459 - accuracy: 0.6037 - val_loss: 0.7116 - val_accuracy: 0.5517
# Epoch 74/100
# 29/29 [==============================] - 1s 21ms/step - loss: 0.6439 - accuracy: 0.6026 - val_loss: 0.7118 - val_accuracy: 0.5539
# Epoch 75/100
# 29/29 [==============================] - 1s 21ms/step - loss: 0.6412 - accuracy: 0.6067 - val_loss: 0.7123 - val_accuracy: 0.5506
# Epoch 76/100
# 29/29 [==============================] - 1s 19ms/step - loss: 0.6402 - accuracy: 0.6091 - val_loss: 0.7162 - val_accuracy: 0.5582
# Epoch 77/100
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6398 - accuracy: 0.6070 - val_loss: 0.7166 - val_accuracy: 0.5582
# Epoch 78/100
# 29/29 [==============================] - 0s 17ms/step - loss: 0.6393 - accuracy: 0.6099 - val_loss: 0.7155 - val_accuracy: 0.5496
# Epoch 79/100
# 29/29 [==============================] - 1s 17ms/step - loss: 0.6373 - accuracy: 0.6102 - val_loss: 0.7152 - val_accuracy: 0.5560
# Epoch 80/100
# 29/29 [==============================] - 0s 14ms/step - loss: 0.6368 - accuracy: 0.6099 - val_loss: 0.7188 - val_accuracy: 0.5550
# Epoch 81/100
# 29/29 [==============================] - 1s 19ms/step - loss: 0.6365 - accuracy: 0.6148 - val_loss: 0.7193 - val_accuracy: 0.5603
# Epoch 82/100
# 29/29 [==============================] - 0s 14ms/step - loss: 0.6364 - accuracy: 0.6123 - val_loss: 0.7195 - val_accuracy: 0.5636
# Epoch 83/100
# 29/29 [==============================] - 1s 53ms/step - loss: 0.6342 - accuracy: 0.6110 - val_loss: 0.7285 - val_accuracy: 0.5679
# Epoch 84/100
# 29/29 [==============================] - 1s 28ms/step - loss: 0.6298 - accuracy: 0.6172 - val_loss: 0.7200 - val_accuracy: 0.5668
# Epoch 85/100
# 29/29 [==============================] - 1s 41ms/step - loss: 0.6318 - accuracy: 0.6137 - val_loss: 0.7218 - val_accuracy: 0.5690
# Epoch 86/100
# 29/29 [==============================] - 1s 28ms/step - loss: 0.6302 - accuracy: 0.6226 - val_loss: 0.7207 - val_accuracy: 0.5539
# Epoch 87/100
# 29/29 [==============================] - 1s 27ms/step - loss: 0.6281 - accuracy: 0.6204 - val_loss: 0.7242 - val_accuracy: 0.5560
# Epoch 88/100
# 29/29 [==============================] - 1s 26ms/step - loss: 0.6359 - accuracy: 0.6207 - val_loss: 0.7231 - val_accuracy: 0.5550
# Epoch 89/100
# 29/29 [==============================] - 1s 25ms/step - loss: 0.6300 - accuracy: 0.6220 - val_loss: 0.7277 - val_accuracy: 0.5614
# Epoch 90/100
# 29/29 [==============================] - 1s 19ms/step - loss: 0.6250 - accuracy: 0.6304 - val_loss: 0.7273 - val_accuracy: 0.5517
# Epoch 91/100
# 29/29 [==============================] - 1s 35ms/step - loss: 0.6284 - accuracy: 0.6258 - val_loss: 0.7248 - val_accuracy: 0.5744
# Epoch 92/100
# 29/29 [==============================] - 1s 20ms/step - loss: 0.6265 - accuracy: 0.6234 - val_loss: 0.7294 - val_accuracy: 0.5550
# Epoch 93/100
# 29/29 [==============================] - 1s 20ms/step - loss: 0.6277 - accuracy: 0.6258 - val_loss: 0.7263 - val_accuracy: 0.5711
# Epoch 94/100
# 29/29 [==============================] - 1s 22ms/step - loss: 0.6239 - accuracy: 0.6253 - val_loss: 0.7304 - val_accuracy: 0.5776
# Epoch 95/100
# 29/29 [==============================] - 1s 20ms/step - loss: 0.6244 - accuracy: 0.6266 - val_loss: 0.7317 - val_accuracy: 0.5582
# Epoch 96/100
# 29/29 [==============================] - 0s 13ms/step - loss: 0.6227 - accuracy: 0.6263 - val_loss: 0.7311 - val_accuracy: 0.5711
# Epoch 97/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6179 - accuracy: 0.6253 - val_loss: 0.7321 - val_accuracy: 0.5690
# Epoch 98/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6204 - accuracy: 0.6288 - val_loss: 0.7304 - val_accuracy: 0.5754
# Epoch 99/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6182 - accuracy: 0.6417 - val_loss: 0.7316 - val_accuracy: 0.5733
# Epoch 100/100
# 29/29 [==============================] - 0s 12ms/step - loss: 0.6176 - accuracy: 0.6334 - val_loss: 0.7373 - val_accuracy: 0.5722
# {'loss': [0.6931165456771851, 0.6930961608886719, 0.6930712461471558, 0.6930243372917175, 0.6929904222488403, 0.6929082274436951, 0.692827045917511, 0.6927238702774048, 0.692584753036499, 0.6924455165863037, 0.6922823190689087, 0.6920990943908691, 0.6918835639953613, 0.6916987299919128, 0.6914779543876648, 0.6912345290184021, 0.6911238431930542, 0.6907798647880554, 0.6906595826148987, 0.6904178857803345, 0.6899198293685913, 0.6895737051963806, 0.6891382932662964, 0.6887208223342896, 0.6884289979934692, 0.6878781318664551, 0.6874555349349976, 0.686905562877655, 0.6866403818130493, 0.6856479644775391, 0.6852543354034424, 0.684259831905365, 0.683743417263031, 0.6828880310058594, 0.6816076636314392, 0.681333065032959, 0.6802021265029907, 0.6787862181663513, 0.6785496473312378, 0.6770750880241394, 0.6750868558883667, 0.6749205589294434, 0.6740159392356873, 0.6743093132972717, 0.6718273162841797, 0.6718223094940186, 0.6703829765319824, 0.6687146425247192, 0.6674723029136658, 0.6673980951309204, 0.6663640737533569, 0.6654013991355896, 0.6654216647148132, 0.6649990081787109, 0.6638092994689941, 0.6618414521217346, 0.66122967004776, 0.6579681038856506, 0.6593254208564758, 0.6583660840988159, 0.6552817821502686, 0.6550937294960022, 0.6547697186470032, 0.6545599102973938, 0.6525604724884033, 0.6506866812705994, 0.6515316367149353, 0.6493417620658875, 0.6480646729469299, 0.6480351090431213, 0.6472702026367188, 0.6497653722763062, 0.6458789110183716, 0.6439378261566162, 0.6412326097488403, 0.6401571035385132, 0.6397573351860046, 0.6392554640769958, 0.6373080611228943, 0.6368357539176941, 0.6365485191345215, 0.6364447474479675, 0.6342262625694275, 0.6298151612281799, 0.6318286657333374, 0.6301630139350891, 0.6280595660209656, 0.6359415650367737, 0.6299874782562256, 0.625043511390686, 0.6284410953521729, 0.6265400648117065, 0.627697229385376, 0.6238917708396912, 0.6243650913238525, 0.6226595640182495, 0.6179425716400146, 0.6204251646995544, 0.61821448802948, 0.6176028847694397], 'accuracy': [0.5053879022598267, 0.5037715435028076, 0.5037715435028076, 0.5037715435028076, 0.5037715435028076, 0.5037715435028076, 0.5037715435028076, 0.5043103694915771, 0.5037715435028076, 0.5037715435028076, 0.5037715435028076, 0.4997306168079376, 0.4940732717514038, 0.501616358757019, 0.5035021305084229, 0.5107758641242981, 0.5121228694915771, 0.5145474076271057, 0.5175107717514038, 0.5164331793785095, 0.5215517282485962, 0.525053858757019, 0.5274784564971924, 0.5261314511299133, 0.5272090435028076, 0.5323275923728943, 0.5390625, 0.537446141242981, 0.5409482717514038, 0.5457974076271057, 0.5519935488700867, 0.5476831793785095, 0.5519935488700867, 0.5447198152542114, 0.5517241358757019, 0.5476831793785095, 0.5592672228813171, 0.5573814511299133, 0.5584590435028076, 0.5598060488700867, 0.5584590435028076, 0.5592672228813171, 0.5600754022598267, 0.5625, 0.564116358757019, 0.5651939511299133, 0.5654633641242981, 0.5786637663841248, 0.579741358757019, 0.5759698152542114, 0.5786637663841248, 0.5775862336158752, 0.5792025923728943, 0.578125, 0.5832435488700867, 0.5786637663841248, 0.5778555870056152, 0.5880926847457886, 0.5824353694915771, 0.584590494632721, 0.5902478694915771, 0.5929418206214905, 0.5897090435028076, 0.5932112336158752, 0.5932112336158752, 0.5926724076271057, 0.603178858757019, 0.6007543206214905, 0.6007543206214905, 0.5967133641242981, 0.5991379022598267, 0.6010237336158752, 0.6037176847457886, 0.6026400923728943, 0.6066810488700867, 0.6091055870056152, 0.6069504022598267, 0.6099137663841248, 0.6101831793785095, 0.6099137663841248, 0.6147629022598267, 0.6123383641242981, 0.610991358757019, 0.6171875, 0.6136853694915771, 0.6225754022598267, 0.6204202771186829, 0.6206896305084229, 0.6220366358757019, 0.6303879022598267, 0.6258081793785095, 0.623383641242981, 0.6258081793785095, 0.6252694129943848, 0.626616358757019, 0.626347005367279, 0.6252694129943848, 0.6287715435028076, 0.6417025923728943, 0.6333512663841248], 'val_loss': [0.6931477785110474, 0.693 ...
# 38/38 [==============================] - 1s 9ms/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 19, 256)           22528
#
#  batch_normalization (Batch  (None, 19, 256)           1024
#  Normalization)
#
#  max_pooling1d (MaxPooling1  (None, 10, 256)           0
#  D)
#
#  conv1d_1 (Conv1D)           (None, 10, 256)           196864
#
#  max_pooling1d_1 (MaxPoolin  (None, 5, 256)            0
#  g1D)
#
#  conv1d_2 (Conv1D)           (None, 5, 512)            393728
#
#  max_pooling1d_2 (MaxPoolin  (None, 3, 512)            0
#  g1D)
#
#  conv1d_3 (Conv1D)           (None, 1, 1024)           1573888
#
#  dropout (Dropout)           (None, 1, 1024)           0
#
#  lstm (LSTM)                 (None, 1, 256)            1311744
#
#  lstm_1 (LSTM)               (None, 1, 256)            525312
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 512)               131584
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dense_2 (Dense)             (None, 32)                8224
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 4296257 (16.39 MB)
# Trainable params: 4295745 (16.39 MB)
# Non-trainable params: 512 (2.00 KB)
# _________________________________________________________________
# Epoch 1/100
# 28/28 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.5079
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 28/28 [==============================] - 8s 77ms/step - loss: 0.6931 - accuracy: 0.5079 - val_loss: 0.6931 - val_accuracy: 0.5057
# Epoch 2/100
# 28/28 [==============================] - 0s 16ms/step - loss: 0.6931 - accuracy: 0.5291 - val_loss: 0.6931 - val_accuracy: 0.5057
# Epoch 3/100
# 28/28 [==============================] - 1s 27ms/step - loss: 0.6930 - accuracy: 0.5303 - val_loss: 0.6931 - val_accuracy: 0.5102
# Epoch 4/100
# 28/28 [==============================] - 1s 18ms/step - loss: 0.6929 - accuracy: 0.5147 - val_loss: 0.6931 - val_accuracy: 0.5079
# Epoch 5/100
# 28/28 [==============================] - 0s 17ms/step - loss: 0.6928 - accuracy: 0.5289 - val_loss: 0.6931 - val_accuracy: 0.5068
# Epoch 6/100
# 28/28 [==============================] - 1s 18ms/step - loss: 0.6927 - accuracy: 0.5308 - val_loss: 0.6931 - val_accuracy: 0.5079
# Epoch 7/100
# 28/28 [==============================] - 1s 18ms/step - loss: 0.6925 - accuracy: 0.5317 - val_loss: 0.6931 - val_accuracy: 0.5102
# Epoch 8/100
# 28/28 [==============================] - 1s 18ms/step - loss: 0.6923 - accuracy: 0.5306 - val_loss: 0.6930 - val_accuracy: 0.5090
# Epoch 9/100
# 28/28 [==============================] - 1s 28ms/step - loss: 0.6920 - accuracy: 0.5263 - val_loss: 0.6930 - val_accuracy: 0.5136
# Epoch 10/100
# 28/28 [==============================] - 1s 23ms/step - loss: 0.6916 - accuracy: 0.5308 - val_loss: 0.6929 - val_accuracy: 0.5181
# Epoch 11/100
# 28/28 [==============================] - 1s 21ms/step - loss: 0.6914 - accuracy: 0.5297 - val_loss: 0.6928 - val_accuracy: 0.5215
# Epoch 12/100
# 28/28 [==============================] - 0s 14ms/step - loss: 0.6910 - accuracy: 0.5314 - val_loss: 0.6927 - val_accuracy: 0.5215
# Epoch 13/100
# 28/28 [==============================] - 1s 21ms/step - loss: 0.6907 - accuracy: 0.5308 - val_loss: 0.6925 - val_accuracy: 0.5283
# Epoch 14/100
# 28/28 [==============================] - 0s 14ms/step - loss: 0.6905 - accuracy: 0.5331 - val_loss: 0.6924 - val_accuracy: 0.5260
# Epoch 15/100
# 28/28 [==============================] - 0s 13ms/step - loss: 0.6902 - accuracy: 0.5365 - val_loss: 0.6923 - val_accuracy: 0.5271
# Epoch 16/100
# 28/28 [==============================] - 1s 24ms/step - loss: 0.6900 - accuracy: 0.5359 - val_loss: 0.6921 - val_accuracy: 0.5317
# Epoch 17/100
# 28/28 [==============================] - 0s 13ms/step - loss: 0.6897 - accuracy: 0.5374 - val_loss: 0.6920 - val_accuracy: 0.5283
# Epoch 18/100
# 28/28 [==============================] - 0s 14ms/step - loss: 0.6894 - accuracy: 0.5388 - val_loss: 0.6919 - val_accuracy: 0.5294
# Epoch 19/100
# 28/28 [==============================] - 0s 15ms/step - loss: 0.6890 - accuracy: 0.5379 - val_loss: 0.6918 - val_accuracy: 0.5283
# Epoch 20/100
# 28/28 [==============================] - 1s 25ms/step - loss: 0.6884 - accuracy: 0.5405 - val_loss: 0.6917 - val_accuracy: 0.5339
# Epoch 21/100
# 28/28 [==============================] - 1s 24ms/step - loss: 0.6883 - accuracy: 0.5399 - val_loss: 0.6917 - val_accuracy: 0.5362
# Epoch 22/100
# 28/28 [==============================] - 1s 24ms/step - loss: 0.6878 - accuracy: 0.5376 - val_loss: 0.6917 - val_accuracy: 0.5396
# Epoch 23/100
# 28/28 [==============================] - 1s 25ms/step - loss: 0.6871 - accuracy: 0.5427 - val_loss: 0.6916 - val_accuracy: 0.5475
# Epoch 24/100
# 28/28 [==============================] - 1s 23ms/step - loss: 0.6865 - accuracy: 0.5467 - val_loss: 0.6918 - val_accuracy: 0.5520
# Epoch 25/100
# 28/28 [==============================] - 1s 28ms/step - loss: 0.6861 - accuracy: 0.5467 - val_loss: 0.6918 - val_accuracy: 0.5532
# Epoch 26/100
# 28/28 [==============================] - 0s 13ms/step - loss: 0.6854 - accuracy: 0.5515 - val_loss: 0.6922 - val_accuracy: 0.5441
# Epoch 27/100
# 28/28 [==============================] - 0s 13ms/step - loss: 0.6846 - accuracy: 0.5566 - val_loss: 0.6923 - val_accuracy: 0.5452
# Epoch 28/100
# 28/28 [==============================] - 0s 17ms/step - loss: 0.6839 - accuracy: 0.5535 - val_loss: 0.6928 - val_accuracy: 0.5486
# Epoch 29/100
# 28/28 [==============================] - 1s 18ms/step - loss: 0.6832 - accuracy: 0.5512 - val_loss: 0.6927 - val_accuracy: 0.5407
# Epoch 30/100
# 28/28 [==============================] - 0s 16ms/step - loss: 0.6822 - accuracy: 0.5594 - val_loss: 0.6934 - val_accuracy: 0.5430
# Epoch 31/100
# 28/28 [==============================] - 1s 18ms/step - loss: 0.6815 - accuracy: 0.5586 - val_loss: 0.6927 - val_accuracy: 0.5419
# Epoch 32/100
# 28/28 [==============================] - 0s 16ms/step - loss: 0.6800 - accuracy: 0.5623 - val_loss: 0.6922 - val_accuracy: 0.5452
# Epoch 33/100
# 28/28 [==============================] - 1s 18ms/step - loss: 0.6794 - accuracy: 0.5642 - val_loss: 0.6938 - val_accuracy: 0.5441
# Epoch 34/100
# 28/28 [==============================] - 1s 50ms/step - loss: 0.6781 - accuracy: 0.5654 - val_loss: 0.6923 - val_accuracy: 0.5464
# Epoch 35/100
# 28/28 [==============================] - 1s 29ms/step - loss: 0.6774 - accuracy: 0.5671 - val_loss: 0.6911 - val_accuracy: 0.5464
# Epoch 36/100
# 28/28 [==============================] - 0s 14ms/step - loss: 0.6766 - accuracy: 0.5724 - val_loss: 0.6953 - val_accuracy: 0.5441
# Epoch 37/100
# 28/28 [==============================] - 0s 16ms/step - loss: 0.6759 - accuracy: 0.5640 - val_loss: 0.6922 - val_accuracy: 0.5441
# Epoch 38/100
# 28/28 [==============================] - 0s 15ms/step - loss: 0.6753 - accuracy: 0.5654 - val_loss: 0.6914 - val_accuracy: 0.5419
# Epoch 39/100
# 28/28 [==============================] - 0s 14ms/step - loss: 0.6740 - accuracy: 0.5750 - val_loss: 0.6910 - val_accuracy: 0.5385
# Epoch 40/100
# 28/28 [==============================] - 0s 14ms/step - loss: 0.6729 - accuracy: 0.5747 - val_loss: 0.6913 - val_accuracy: 0.5430
# Epoch 41/100
# 28/28 [==============================] - 0s 13ms/step - loss: 0.6723 - accuracy: 0.5736 - val_loss: 0.6892 - val_accuracy: 0.5532
# Epoch 42/100
# 28/28 [==============================] - 0s 13ms/step - loss: 0.6706 - accuracy: 0.5770 - val_loss: 0.6943 - val_accuracy: 0.5475
# Epoch 43/100
# 28/28 [==============================] - 1s 52ms/step - loss: 0.6696 - accuracy: 0.5758 - val_loss: 0.6902 - val_accuracy: 0.5554
# Epoch 44/100
# 28/28 [==============================] - 0s 13ms/step - loss: 0.6695 - accuracy: 0.5821 - val_loss: 0.6902 - val_accuracy: 0.5509
# Epoch 45/100
# 28/28 [==============================] - 0s 13ms/step - loss: 0.6685 - accuracy: 0.5801 - val_loss: 0.6918 - val_accuracy: 0.5464
# Epoch 46/100
# 28/28 [==============================] - 0s 13ms/step - loss: 0.6679 - accuracy: 0.5792 - val_loss: 0.6941 - val_accuracy: 0.5532
# Epoch 47/100
# 28/28 [==============================] - 0s 13ms/step - loss: 0.6676 - accuracy: 0.5778 - val_loss: 0.6908 - val_accuracy: 0.5520
# Epoch 48/100
# 28/28 [==============================] - 0s 13ms/step - loss: 0.6662 - accuracy: 0.5792 - val_loss: 0.6926 - val_accuracy: 0.5475
# Epoch 49/100
# 28/28 [==============================] - 0s 14ms/step - loss: 0.6649 - accuracy: 0.5835 - val_loss: 0.6937 - val_accuracy: 0.5509
# Epoch 50/100
# 28/28 [==============================] - 0s 13ms/step - loss: 0.6640 - accuracy: 0.5891 - val_loss: 0.6931 - val_accuracy: 0.5498
# Epoch 51/100
# 28/28 [==============================] - 0s 13ms/step - loss: 0.6656 - accuracy: 0.5767 - val_loss: 0.6950 - val_accuracy: 0.5543
# Epoch 52/100
# 28/28 [==============================] - 0s 13ms/step - loss: 0.6623 - accuracy: 0.5860 - val_loss: 0.6959 - val_accuracy: 0.5554
# Epoch 53/100
# 28/28 [==============================] - 0s 15ms/step - loss: 0.6622 - accuracy: 0.5843 - val_loss: 0.6951 - val_accuracy: 0.5509
# Epoch 54/100
# 28/28 [==============================] - 0s 14ms/step - loss: 0.6624 - accuracy: 0.5894 - val_loss: 0.7008 - val_accuracy: 0.5498
# Epoch 55/100
# 28/28 [==============================] - 0s 13ms/step - loss: 0.6625 - accuracy: 0.5815 - val_loss: 0.6962 - val_accuracy: 0.5543
# Epoch 56/100
# 28/28 [==============================] - 0s 15ms/step - loss: 0.6598 - accuracy: 0.5897 - val_loss: 0.6959 - val_accuracy: 0.5498
# Epoch 57/100
# 28/28 [==============================] - 0s 13ms/step - loss: 0.6618 - accuracy: 0.5866 - val_loss: 0.6973 - val_accuracy: 0.5520
# Epoch 58/100
# 28/28 [==============================] - 0s 15ms/step - loss: 0.6597 - accuracy: 0.5894 - val_loss: 0.6967 - val_accuracy: 0.5532
# Epoch 59/100
# 28/28 [==============================] - 1s 22ms/step - loss: 0.6585 - accuracy: 0.5866 - val_loss: 0.7006 - val_accuracy: 0.5554
# Epoch 60/100
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6579 - accuracy: 0.5939 - val_loss: 0.6989 - val_accuracy: 0.5532
# Epoch 61/100
# 28/28 [==============================] - 1s 20ms/step - loss: 0.6597 - accuracy: 0.5905 - val_loss: 0.6978 - val_accuracy: 0.5520
# Epoch 62/100
# 28/28 [==============================] - 1s 18ms/step - loss: 0.6578 - accuracy: 0.5948 - val_loss: 0.6982 - val_accuracy: 0.5543
# Epoch 63/100
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6564 - accuracy: 0.5891 - val_loss: 0.7007 - val_accuracy: 0.5498
# Epoch 64/100
# 28/28 [==============================] - 2s 57ms/step - loss: 0.6552 - accuracy: 0.5917 - val_loss: 0.7043 - val_accuracy: 0.5600
# Epoch 65/100
# 28/28 [==============================] - 1s 18ms/step - loss: 0.6563 - accuracy: 0.5874 - val_loss: 0.7002 - val_accuracy: 0.5543
# Epoch 66/100
# 28/28 [==============================] - 0s 14ms/step - loss: 0.6554 - accuracy: 0.5891 - val_loss: 0.7028 - val_accuracy: 0.5554
# Epoch 67/100
# 28/28 [==============================] - 0s 14ms/step - loss: 0.6543 - accuracy: 0.5931 - val_loss: 0.7065 - val_accuracy: 0.5577
# Epoch 68/100
# 28/28 [==============================] - 1s 22ms/step - loss: 0.6516 - accuracy: 0.5976 - val_loss: 0.7059 - val_accuracy: 0.5656
# Epoch 69/100
# 28/28 [==============================] - 1s 24ms/step - loss: 0.6517 - accuracy: 0.5968 - val_loss: 0.7152 - val_accuracy: 0.5679
# Epoch 70/100
# 28/28 [==============================] - 0s 15ms/step - loss: 0.6532 - accuracy: 0.5937 - val_loss: 0.7054 - val_accuracy: 0.5577
# Epoch 71/100
# 28/28 [==============================] - 0s 15ms/step - loss: 0.6492 - accuracy: 0.6038 - val_loss: 0.7050 - val_accuracy: 0.5532
# Epoch 72/100
# 28/28 [==============================] - 0s 15ms/step - loss: 0.6505 - accuracy: 0.5985 - val_loss: 0.7039 - val_accuracy: 0.5532
# Epoch 73/100
# 28/28 [==============================] - 0s 15ms/step - loss: 0.6491 - accuracy: 0.6027 - val_loss: 0.7028 - val_accuracy: 0.5577
# Epoch 74/100
# 28/28 [==============================] - 0s 15ms/step - loss: 0.6472 - accuracy: 0.6027 - val_loss: 0.7096 - val_accuracy: 0.5645
# Epoch 75/100
# 28/28 [==============================] - 0s 13ms/step - loss: 0.6483 - accuracy: 0.6027 - val_loss: 0.7044 - val_accuracy: 0.5554
# Epoch 76/100
# 28/28 [==============================] - 1s 22ms/step - loss: 0.6460 - accuracy: 0.6047 - val_loss: 0.7118 - val_accuracy: 0.5690
# Epoch 77/100
# 28/28 [==============================] - 0s 15ms/step - loss: 0.6450 - accuracy: 0.6075 - val_loss: 0.7071 - val_accuracy: 0.5633
# Epoch 78/100
# 28/28 [==============================] - 0s 15ms/step - loss: 0.6449 - accuracy: 0.6072 - val_loss: 0.7094 - val_accuracy: 0.5667
# Epoch 79/100
# 28/28 [==============================] - 0s 13ms/step - loss: 0.6454 - accuracy: 0.6072 - val_loss: 0.7057 - val_accuracy: 0.5633
# Epoch 80/100
# 28/28 [==============================] - 0s 15ms/step - loss: 0.6454 - accuracy: 0.6089 - val_loss: 0.7086 - val_accuracy: 0.5566
# Epoch 81/100
# 28/28 [==============================] - 0s 15ms/step - loss: 0.6436 - accuracy: 0.6092 - val_loss: 0.7096 - val_accuracy: 0.5633
# Epoch 82/100
# 28/28 [==============================] - 0s 14ms/step - loss: 0.6411 - accuracy: 0.6104 - val_loss: 0.7116 - val_accuracy: 0.5656
# Epoch 83/100
# 28/28 [==============================] - 0s 14ms/step - loss: 0.6394 - accuracy: 0.6174 - val_loss: 0.7143 - val_accuracy: 0.5656
# Epoch 84/100
# 28/28 [==============================] - 0s 13ms/step - loss: 0.6403 - accuracy: 0.6152 - val_loss: 0.7139 - val_accuracy: 0.5588
# Epoch 85/100
# 28/28 [==============================] - 0s 13ms/step - loss: 0.6377 - accuracy: 0.6109 - val_loss: 0.7194 - val_accuracy: 0.5679
# Epoch 86/100
# 28/28 [==============================] - 1s 28ms/step - loss: 0.6405 - accuracy: 0.6140 - val_loss: 0.7161 - val_accuracy: 0.5724
# Epoch 87/100
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6376 - accuracy: 0.6140 - val_loss: 0.7207 - val_accuracy: 0.5656
# Epoch 88/100
# 28/28 [==============================] - 1s 18ms/step - loss: 0.6337 - accuracy: 0.6203 - val_loss: 0.7183 - val_accuracy: 0.5622
# Epoch 89/100
# 28/28 [==============================] - 0s 17ms/step - loss: 0.6355 - accuracy: 0.6166 - val_loss: 0.7214 - val_accuracy: 0.5667
# Epoch 90/100
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6320 - accuracy: 0.6211 - val_loss: 0.7183 - val_accuracy: 0.5633
# Epoch 91/100
# 28/28 [==============================] - 1s 21ms/step - loss: 0.6351 - accuracy: 0.6228 - val_loss: 0.7334 - val_accuracy: 0.5713
# Epoch 92/100
# 28/28 [==============================] - 1s 18ms/step - loss: 0.6324 - accuracy: 0.6271 - val_loss: 0.7366 - val_accuracy: 0.5690
# Epoch 93/100
# 28/28 [==============================] - 1s 19ms/step - loss: 0.6284 - accuracy: 0.6279 - val_loss: 0.7363 - val_accuracy: 0.5713
# Epoch 94/100
# 28/28 [==============================] - 1s 22ms/step - loss: 0.6298 - accuracy: 0.6228 - val_loss: 0.7252 - val_accuracy: 0.5735
# Epoch 95/100
# 28/28 [==============================] - 0s 14ms/step - loss: 0.6274 - accuracy: 0.6222 - val_loss: 0.7287 - val_accuracy: 0.5656
# Epoch 96/100
# 28/28 [==============================] - 0s 13ms/step - loss: 0.6280 - accuracy: 0.6271 - val_loss: 0.7275 - val_accuracy: 0.5622
# Epoch 97/100
# 28/28 [==============================] - 0s 14ms/step - loss: 0.6240 - accuracy: 0.6287 - val_loss: 0.7266 - val_accuracy: 0.5577
# Epoch 98/100
# 28/28 [==============================] - 0s 13ms/step - loss: 0.6248 - accuracy: 0.6296 - val_loss: 0.7311 - val_accuracy: 0.5611
# Epoch 99/100
# 28/28 [==============================] - 0s 14ms/step - loss: 0.6237 - accuracy: 0.6341 - val_loss: 0.7358 - val_accuracy: 0.5713
# Epoch 100/100
# 28/28 [==============================] - 0s 14ms/step - loss: 0.6205 - accuracy: 0.6302 - val_loss: 0.7360 - val_accuracy: 0.5622
# {'loss': [0.6931037902832031, 0.6930601596832275, 0.6930021047592163, 0.6929131746292114, 0.6928128004074097, 0.692701518535614, 0.6925256252288818, 0.6922826170921326, 0.6919928193092346, 0.6916244626045227, 0.6913504600524902, 0.6909787058830261, 0.6907216310501099, 0.6905160546302795, 0.6901912093162537, 0.6899533867835999, 0.6896623373031616, 0.689360499382019, 0.6890026330947876, 0.6883962154388428, 0.6882532238960266, 0.6877596378326416, 0.6871318817138672, 0.6865244507789612, 0.6860964894294739, 0.6854130625724792, 0.6846030354499817, 0.6839063763618469, 0.6831594109535217, 0.6822496652603149, 0.681525468826294, 0.6800464987754822, 0.6793660521507263, 0.6781153678894043, 0.6774316430091858, 0.676642656326294, 0.6758599877357483, 0.6753089427947998, 0.6739957928657532, 0.6728798151016235, 0.672330379486084, 0.6705634593963623, 0.669589638710022, 0.6695330739021301, 0.6685485243797302, 0.6678837537765503, 0.6676139235496521, 0.6662124991416931, 0.6649232506752014, 0.6639636158943176, 0.6656437516212463, 0.6622775197029114, 0.6621941328048706, 0.6624068021774292, 0.6624642610549927, 0.6598260402679443, 0.6617869138717651, 0.6596772074699402, 0.6584697365760803, 0.6579026579856873, 0.6596928834915161, 0.6577885150909424, 0.656417191028595, 0.6552165150642395, 0.656309962272644, 0.6554107666015625, 0.6543444991111755, 0.6515752673149109, 0.651684582233429, 0.6532422304153442, 0.6492182016372681, 0.6504555344581604, 0.6490617394447327, 0.647213876247406, 0.6482860445976257, 0.646038830280304, 0.6450371742248535, 0.6449387073516846, 0.6453575491905212, 0.6453801393508911, 0.6435645818710327, 0.6411250233650208, 0.6393848061561584, 0.640315592288971, 0.6377306580543518, 0.6404813528060913, 0.6376258730888367, 0.6337363123893738, 0.6355264186859131, 0.6319578289985657, 0.6351417899131775, 0.6324414014816284, 0.6284182667732239, 0.6298332810401917, 0.6273680329322815, 0.6280479431152344, 0.6240372061729431, 0.6248262524604797, 0.6237493753433228, 0.6205050945281982], 'accuracy': [0.5079230070114136, 0.5291454195976257, 0.5302773118019104, 0.5147141814231873, 0.528862476348877, 0.5308432579040527, 0.5316921472549438, 0.5305602550506592, 0.5263158082962036, 0.5308432579040527, 0.5297113656997681, 0.5314091444015503, 0.5308432579040527, 0.5331069827079773, 0.5365025401115417, 0.5359365940093994, 0.5373514294624329, 0.5387662649154663, 0.5379173755645752, 0.5404640436172485, 0.539898157119751, 0.5376344323158264, 0.5427277684211731, 0.5466893315315247, 0.5466893315315247, 0.5514997243881226, 0.556593120098114, 0.5534804463386536, 0.5512167811393738, 0.5594227313995361, 0.558573842048645, 0.562252402305603, 0.5642331838607788, 0.5653650164604187, 0.5670627951622009, 0.5724391341209412, 0.5639501810073853, 0.5653650164604187, 0.5749858617782593, 0.5747028589248657, 0.5735710263252258, 0.5769665837287903, 0.5758347511291504, 0.5820599794387817, 0.5800792574882507, 0.5792303085327148, 0.5778155326843262, 0.5792303085327148, 0.5834748148918152, 0.5891340970993042, 0.5766836404800415, 0.5860214829444885, 0.5843237042427063, 0.5894170999526978, 0.5814940333366394, 0.5897000432014465, 0.5865874290466309, 0.5894170999526978, 0.5865874290466309, 0.5939445495605469, 0.5905489325523376, 0.594793438911438, 0.5891340970993042, 0.5916808247566223, 0.587436318397522, 0.5891340970993042, 0.5930956602096558, 0.5976231098175049, 0.5967742204666138, 0.5936615467071533, 0.6038483381271362, 0.598471999168396, 0.6027164459228516, 0.6027164459228516, 0.6027164459228516, 0.6046972274780273, 0.6075268983840942, 0.6072438955307007, 0.6072438955307007, 0.6089417338371277, 0.6092246770858765, 0.6103565096855164, 0.6174306869506836, 0.615166962146759, 0.6109224557876587, 0.6140350699424744, 0.6140350699424744, 0.6202603578567505, 0.6165817975997925, 0.6211092472076416, 0.6228070259094238, 0.6270514726638794, 0.6279004216194153, 0.6228070259094238, 0.6222410798072815, 0.6270514726638794, 0.6287493109703064, 0.6295982003211975, 0.6341256499290466, 0.630164146423339 ...
# 45/45 [==============================] - 1s 6ms/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 19, 256)           22528
#
#  batch_normalization (Batch  (None, 19, 256)           1024
#  Normalization)
#
#  max_pooling1d (MaxPooling1  (None, 10, 256)           0
#  D)
#
#  conv1d_1 (Conv1D)           (None, 10, 256)           196864
#
#  max_pooling1d_1 (MaxPoolin  (None, 5, 256)            0
#  g1D)
#
#  conv1d_2 (Conv1D)           (None, 5, 512)            393728
#
#  max_pooling1d_2 (MaxPoolin  (None, 3, 512)            0
#  g1D)
#
#  conv1d_3 (Conv1D)           (None, 1, 1024)           1573888
#
#  dropout (Dropout)           (None, 1, 1024)           0
#
# ...
# Epoch 18/100
# 31/31 [==============================] - 1s 29ms/step - loss: 0.3847 - accuracy: 0.8127 - val_loss: 0.6671 - val_accuracy: 0.6457
# Epoch 19/100
# 31/31 [==============================] - 1s 19ms/step - loss: 0.3853 - accuracy: 0.8072 - val_loss: 0.6737 - val_accuracy: 0.6446
# Epoch 20/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.3928 - accuracy: 0.8049 - val_loss: 0.6786 - val_accuracy: 0.6426
# Epoch 21/100
# 31/31 [==============================] - 1s 28ms/step - loss: 0.3949 - accuracy: 0.8101 - val_loss: 0.6863 - val_accuracy: 0.6529
# Epoch 22/100
# 31/31 [==============================] - 1s 20ms/step - loss: 0.3901 - accuracy: 0.8096 - val_loss: 0.7095 - val_accuracy: 0.6384
# Epoch 23/100
# 31/31 [==============================] - 1s 27ms/step - loss: 0.3884 - accuracy: 0.8085 - val_loss: 0.7113 - val_accuracy: 0.6581
# Epoch 24/100
# 31/31 [==============================] - 0s 14ms/step - loss: 0.3804 - accuracy: 0.8132 - val_loss: 0.7179 - val_accuracy: 0.6519
# Epoch 25/100
# 31/31 [==============================] - 1s 21ms/step - loss: 0.3817 - accuracy: 0.8140 - val_loss: 0.7088 - val_accuracy: 0.6601
# Epoch 26/100
# 31/31 [==============================] - 0s 14ms/step - loss: 0.3799 - accuracy: 0.8171 - val_loss: 0.7481 - val_accuracy: 0.6436
# Epoch 27/100
# 31/31 [==============================] - 0s 13ms/step - loss: 0.3756 - accuracy: 0.8140 - val_loss: 0.7755 - val_accuracy: 0.6415
# Epoch 28/100
# 31/31 [==============================] - 0s 13ms/step - loss: 0.3700 - accuracy: 0.8202 - val_loss: 0.7604 - val_accuracy: 0.6436
# Epoch 29/100
# 31/31 [==============================] - 0s 14ms/step - loss: 0.3737 - accuracy: 0.8230 - val_loss: 0.7682 - val_accuracy: 0.6570
# Epoch 30/100
# 31/31 [==============================] - 0s 14ms/step - loss: 0.3681 - accuracy: 0.8137 - val_loss: 0.7581 - val_accuracy: 0.6488
# Epoch 31/100
# 31/31 [==============================] - 0s 13ms/step - loss: 0.3710 - accuracy: 0.8171 - val_loss: 0.7789 - val_accuracy: 0.6467
# Epoch 32/100
# 31/31 [==============================] - 0s 14ms/step - loss: 0.3703 - accuracy: 0.8152 - val_loss: 0.8196 - val_accuracy: 0.6508
# Epoch 33/100
# 31/31 [==============================] - 0s 13ms/step - loss: 0.3743 - accuracy: 0.8183 - val_loss: 0.8675 - val_accuracy: 0.6209
# Epoch 34/100
# 31/31 [==============================] - 0s 15ms/step - loss: 0.3693 - accuracy: 0.8230 - val_loss: 0.8167 - val_accuracy: 0.6457
# Epoch 35/100
# 31/31 [==============================] - 0s 13ms/step - loss: 0.3594 - accuracy: 0.8302 - val_loss: 0.8297 - val_accuracy: 0.6560
# Epoch 36/100
# 31/31 [==============================] - 0s 14ms/step - loss: 0.3741 - accuracy: 0.8165 - val_loss: 0.8184 - val_accuracy: 0.6529
# Epoch 37/100
# 31/31 [==============================] - 0s 14ms/step - loss: 0.3663 - accuracy: 0.8189 - val_loss: 0.8009 - val_accuracy: 0.6488
# Epoch 38/100
# 31/31 [==============================] - 1s 20ms/step - loss: 0.3650 - accuracy: 0.8183 - val_loss: 0.8120 - val_accuracy: 0.6632
# Epoch 39/100
# 31/31 [==============================] - 0s 14ms/step - loss: 0.3581 - accuracy: 0.8302 - val_loss: 0.8633 - val_accuracy: 0.6488
# Epoch 40/100
# 31/31 [==============================] - 0s 13ms/step - loss: 0.3593 - accuracy: 0.8214 - val_loss: 0.8103 - val_accuracy: 0.6477
# Epoch 41/100
# 31/31 [==============================] - 0s 13ms/step - loss: 0.3548 - accuracy: 0.8271 - val_loss: 0.8956 - val_accuracy: 0.6260
# Epoch 42/100
# 31/31 [==============================] - 0s 13ms/step - loss: 0.3550 - accuracy: 0.8318 - val_loss: 0.8428 - val_accuracy: 0.6271
# Epoch 43/100
# 31/31 [==============================] - 0s 13ms/step - loss: 0.3492 - accuracy: 0.8313 - val_loss: 0.8698 - val_accuracy: 0.6291
# Epoch 44/100
# 31/31 [==============================] - 0s 14ms/step - loss: 0.3574 - accuracy: 0.8269 - val_loss: 0.8055 - val_accuracy: 0.6591
# Epoch 45/100
# 31/31 [==============================] - 0s 13ms/step - loss: 0.3510 - accuracy: 0.8222 - val_loss: 0.8531 - val_accuracy: 0.6333
# Epoch 46/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.3657 - accuracy: 0.8251 - val_loss: 0.8372 - val_accuracy: 0.6343
# Epoch 47/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.3575 - accuracy: 0.8171 - val_loss: 0.9487 - val_accuracy: 0.6353
# Epoch 48/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.3603 - accuracy: 0.8253 - val_loss: 0.9009 - val_accuracy: 0.6333
# Epoch 49/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.3533 - accuracy: 0.8243 - val_loss: 0.8722 - val_accuracy: 0.6395
# Epoch 50/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.3584 - accuracy: 0.8227 - val_loss: 0.8363 - val_accuracy: 0.6364
# Epoch 51/100
# 31/31 [==============================] - 1s 19ms/step - loss: 0.3564 - accuracy: 0.8222 - val_loss: 0.8238 - val_accuracy: 0.6281
# Epoch 52/100
# 31/31 [==============================] - 1s 19ms/step - loss: 0.3519 - accuracy: 0.8248 - val_loss: 0.8487 - val_accuracy: 0.6302
# Epoch 53/100
# 31/31 [==============================] - 1s 19ms/step - loss: 0.3635 - accuracy: 0.8292 - val_loss: 0.8674 - val_accuracy: 0.6550
# Epoch 54/100
# 31/31 [==============================] - 0s 13ms/step - loss: 0.3528 - accuracy: 0.8307 - val_loss: 0.8752 - val_accuracy: 0.6539
# Epoch 55/100
# 31/31 [==============================] - 0s 16ms/step - loss: 0.3396 - accuracy: 0.8364 - val_loss: 0.8819 - val_accuracy: 0.6426
# Epoch 56/100
# 31/31 [==============================] - 0s 15ms/step - loss: 0.3411 - accuracy: 0.8323 - val_loss: 0.8566 - val_accuracy: 0.6539
# Epoch 57/100
# 31/31 [==============================] - 0s 14ms/step - loss: 0.3337 - accuracy: 0.8460 - val_loss: 0.8663 - val_accuracy: 0.6591
# Epoch 58/100
# 31/31 [==============================] - 0s 14ms/step - loss: 0.3382 - accuracy: 0.8341 - val_loss: 0.8621 - val_accuracy: 0.6488
# Epoch 59/100
# 31/31 [==============================] - 0s 14ms/step - loss: 0.3377 - accuracy: 0.8411 - val_loss: 0.9194 - val_accuracy: 0.6250
# Epoch 60/100
# 31/31 [==============================] - 0s 13ms/step - loss: 0.3332 - accuracy: 0.8354 - val_loss: 0.8690 - val_accuracy: 0.6519
# Epoch 61/100
# 31/31 [==============================] - 0s 13ms/step - loss: 0.3403 - accuracy: 0.8351 - val_loss: 0.8553 - val_accuracy: 0.6364
# Epoch 62/100
# 31/31 [==============================] - 0s 15ms/step - loss: 0.3401 - accuracy: 0.8331 - val_loss: 0.8616 - val_accuracy: 0.6498
# Epoch 63/100
# 31/31 [==============================] - 0s 14ms/step - loss: 0.3325 - accuracy: 0.8372 - val_loss: 0.9213 - val_accuracy: 0.6457
# Epoch 64/100
# 31/31 [==============================] - 0s 14ms/step - loss: 0.3472 - accuracy: 0.8318 - val_loss: 0.8693 - val_accuracy: 0.6467
# Epoch 65/100
# 31/31 [==============================] - 0s 14ms/step - loss: 0.3447 - accuracy: 0.8346 - val_loss: 1.0356 - val_accuracy: 0.6074
# Epoch 66/100
# 31/31 [==============================] - 0s 13ms/step - loss: 0.3383 - accuracy: 0.8406 - val_loss: 0.8994 - val_accuracy: 0.6322
# Epoch 67/100
# 31/31 [==============================] - 0s 15ms/step - loss: 0.3237 - accuracy: 0.8439 - val_loss: 0.8695 - val_accuracy: 0.6508
# Epoch 68/100
# 31/31 [==============================] - 0s 13ms/step - loss: 0.3328 - accuracy: 0.8328 - val_loss: 0.9389 - val_accuracy: 0.6271
# Epoch 69/100
# 31/31 [==============================] - 0s 15ms/step - loss: 0.3299 - accuracy: 0.8517 - val_loss: 0.9664 - val_accuracy: 0.6219
# Epoch 70/100
# 31/31 [==============================] - 0s 13ms/step - loss: 0.3304 - accuracy: 0.8434 - val_loss: 0.9559 - val_accuracy: 0.6322
# Epoch 71/100
# 31/31 [==============================] - 0s 14ms/step - loss: 0.3171 - accuracy: 0.8413 - val_loss: 0.9566 - val_accuracy: 0.6333
# Epoch 72/100
# 31/31 [==============================] - 0s 13ms/step - loss: 0.3235 - accuracy: 0.8444 - val_loss: 1.0419 - val_accuracy: 0.6364
# Epoch 73/100
# 31/31 [==============================] - 0s 15ms/step - loss: 0.3293 - accuracy: 0.8398 - val_loss: 0.8957 - val_accuracy: 0.6508
# Epoch 74/100
# 31/31 [==============================] - 0s 14ms/step - loss: 0.3302 - accuracy: 0.8463 - val_loss: 0.9356 - val_accuracy: 0.6250
# Epoch 75/100
# 31/31 [==============================] - 0s 13ms/step - loss: 0.3306 - accuracy: 0.8364 - val_loss: 0.9327 - val_accuracy: 0.6395
# Epoch 76/100
# 31/31 [==============================] - 0s 16ms/step - loss: 0.3298 - accuracy: 0.8455 - val_loss: 0.9453 - val_accuracy: 0.6446
# Epoch 77/100
# 31/31 [==============================] - 1s 17ms/step - loss: 0.3157 - accuracy: 0.8509 - val_loss: 0.9850 - val_accuracy: 0.6405
# Epoch 78/100
# 31/31 [==============================] - 1s 19ms/step - loss: 0.3211 - accuracy: 0.8413 - val_loss: 0.9299 - val_accuracy: 0.6229
# Epoch 79/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.3220 - accuracy: 0.8455 - val_loss: 0.9298 - val_accuracy: 0.6281
# Epoch 80/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.3276 - accuracy: 0.8537 - val_loss: 0.9639 - val_accuracy: 0.6250
# Epoch 81/100
# 31/31 [==============================] - 1s 19ms/step - loss: 0.3197 - accuracy: 0.8486 - val_loss: 0.9291 - val_accuracy: 0.6374
# Epoch 82/100
# 31/31 [==============================] - 1s 20ms/step - loss: 0.3161 - accuracy: 0.8478 - val_loss: 0.9028 - val_accuracy: 0.6260
# Epoch 83/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.3209 - accuracy: 0.8457 - val_loss: 0.9855 - val_accuracy: 0.6364
# Epoch 84/100
# 31/31 [==============================] - 1s 18ms/step - loss: 0.3286 - accuracy: 0.8444 - val_loss: 0.9683 - val_accuracy: 0.6384
# Epoch 85/100
# 31/31 [==============================] - 0s 14ms/step - loss: 0.3125 - accuracy: 0.8537 - val_loss: 1.0291 - val_accuracy: 0.6178
# Epoch 86/100
# 31/31 [==============================] - 0s 13ms/step - loss: 0.3075 - accuracy: 0.8509 - val_loss: 0.9897 - val_accuracy: 0.6364
# Epoch 87/100
# 31/31 [==============================] - 0s 14ms/step - loss: 0.3167 - accuracy: 0.8494 - val_loss: 0.9110 - val_accuracy: 0.6384
# Epoch 88/100
# 31/31 [==============================] - 0s 13ms/step - loss: 0.3091 - accuracy: 0.8468 - val_loss: 0.9635 - val_accuracy: 0.6457
# Epoch 89/100
# 31/31 [==============================] - 0s 13ms/step - loss: 0.3100 - accuracy: 0.8452 - val_loss: 0.9832 - val_accuracy: 0.6415
# Epoch 90/100
# 31/31 [==============================] - 0s 14ms/step - loss: 0.3134 - accuracy: 0.8556 - val_loss: 0.9509 - val_accuracy: 0.6353
# Epoch 91/100
# 31/31 [==============================] - 0s 13ms/step - loss: 0.3106 - accuracy: 0.8553 - val_loss: 1.0339 - val_accuracy: 0.6322
# Epoch 92/100
# 31/31 [==============================] - 0s 13ms/step - loss: 0.3043 - accuracy: 0.8594 - val_loss: 0.9577 - val_accuracy: 0.6333
# Epoch 93/100
# 31/31 [==============================] - 0s 14ms/step - loss: 0.3194 - accuracy: 0.8429 - val_loss: 1.1525 - val_accuracy: 0.6064
# Epoch 94/100
# 31/31 [==============================] - 0s 14ms/step - loss: 0.3139 - accuracy: 0.8535 - val_loss: 1.0487 - val_accuracy: 0.6364
# Epoch 95/100
# 31/31 [==============================] - 0s 13ms/step - loss: 0.2964 - accuracy: 0.8607 - val_loss: 1.0042 - val_accuracy: 0.6519
# Epoch 96/100
# 31/31 [==============================] - 0s 13ms/step - loss: 0.3004 - accuracy: 0.8574 - val_loss: 1.0308 - val_accuracy: 0.6353
# Epoch 97/100
# 31/31 [==============================] - 0s 13ms/step - loss: 0.3006 - accuracy: 0.8514 - val_loss: 1.0757 - val_accuracy: 0.6312
# Epoch 98/100
# 31/31 [==============================] - 0s 14ms/step - loss: 0.2948 - accuracy: 0.8597 - val_loss: 1.0634 - val_accuracy: 0.6281
# Epoch 99/100
# 31/31 [==============================] - 0s 15ms/step - loss: 0.2926 - accuracy: 0.8607 - val_loss: 1.1067 - val_accuracy: 0.6116
# Epoch 100/100
# 31/31 [==============================] - 0s 14ms/step - loss: 0.3202 - accuracy: 0.8437 - val_loss: 1.0542 - val_accuracy: 0.6260
# {'loss': [0.4402902126312256, 0.4246680438518524, 0.4135923981666565, 0.41546177864074707, 0.4108722507953644, 0.4067545235157013, 0.3969629406929016, 0.4108721613883972, 0.407120019197464, 0.3963157832622528, 0.39986124634742737, 0.40236735343933105, 0.3926492929458618, 0.3995817303657532, 0.4040011763572693, 0.38026195764541626, 0.38829803466796875, 0.3847181797027588, 0.3853220045566559, 0.39278432726860046, 0.39490532875061035, 0.39005765318870544, 0.38835588097572327, 0.38036012649536133, 0.38168007135391235, 0.37988048791885376, 0.3756459355354309, 0.36998218297958374, 0.3737286627292633, 0.36811599135398865, 0.371021032333374, 0.3703484535217285, 0.3743254542350769, 0.369290292263031, 0.35941311717033386, 0.37414219975471497, 0.36632001399993896, 0.36499765515327454, 0.35805052518844604, 0.3592783212661743, 0.3547792136669159, 0.3549814522266388, 0.349159300327301, 0.3573889434337616, 0.3510268032550812, 0.36567047238349915, 0.35748961567878723, 0.3603103756904602, 0.3533076047897339, 0.3583880066871643, 0.3564154803752899, 0.35194432735443115, 0.3634904623031616, 0.3527580201625824, 0.3396233916282654, 0.34109440445899963, 0.33367642760276794, 0.33818909525871277, 0.3376924693584442, 0.3331991136074066, 0.34031233191490173, 0.34014883637428284, 0.3324890434741974, 0.3472215235233307, 0.34465131163597107, 0.3383232355117798, 0.32373908162117004, 0.3328419625759125, 0.3298715054988861, 0.33042478561401367, 0.31705760955810547, 0.3235018253326416, 0.3293401896953583, 0.330188512802124, 0.33062589168548584, 0.3298419713973999, 0.31574496626853943, 0.32114022970199585, 0.32198262214660645, 0.3275594115257263, 0.31974855065345764, 0.316127747297287, 0.3209470212459564, 0.32857367396354675, 0.312497615814209, 0.30751723051071167, 0.31672751903533936, 0.3091123104095459, 0.31002187728881836, 0.31343695521354675, 0.3105834126472473, 0.30433225631713867, 0.3194206953048706, 0.31389373540878296, 0.29641401767730713, 0.3004462420940399, 0.3006386160850525, 0.29481372237205505, 0.2925642430782318, 0.3202071487903595], 'accuracy': [0.777260959148407, 0.7956072092056274, 0.7909560799598694, 0.786821722984314, 0.7979328036308289, 0.7976744174957275, 0.8067183494567871, 0.7922480702400208, 0.7935400605201721, 0.8031007647514343, 0.8059431314468384, 0.800000011920929, 0.8062015771865845, 0.8007751703262329, 0.8023256063461304, 0.817054271697998, 0.8105943202972412, 0.8126614689826965, 0.8072351217269897, 0.8049095869064331, 0.8100775480270386, 0.8095607161521912, 0.8085271120071411, 0.813178300857544, 0.8139534592628479, 0.817054271697998, 0.8139534592628479, 0.8201550245285034, 0.8229973912239075, 0.8136950731277466, 0.817054271697998, 0.8152454495429993, 0.8183462619781494, 0.8229973912239075, 0.830232560634613, 0.8165374398231506, 0.818863034248352, 0.8183462619781494, 0.830232560634613, 0.8214470148086548, 0.8271318078041077, 0.8317829370498657, 0.8312661647796631, 0.8268733620643616, 0.8222222328186035, 0.8250645995140076, 0.817054271697998, 0.8253229856491089, 0.8242893815040588, 0.8227390050888062, 0.8222222328186035, 0.8248062133789062, 0.829198956489563, 0.8307493329048157, 0.8364341259002686, 0.8322997689247131, 0.8459948301315308, 0.8341085314750671, 0.8410852551460266, 0.8354005217552185, 0.8351421356201172, 0.8330749273300171, 0.8372092843055725, 0.8317829370498657, 0.8346253037452698, 0.840568482875824, 0.8439276218414307, 0.8328165411949158, 0.8516795635223389, 0.843410849571228, 0.8413436412811279, 0.8444444537162781, 0.8397932648658752, 0.8462532162666321, 0.8364341259002686, 0.8454780578613281, 0.8509044051170349, 0.8413436412811279, 0.8454780578613281, 0.853746771812439, 0.8485788106918335, 0.8478035926818848, 0.8457364439964294, 0.8444444537162781, 0.853746771812439, 0.8509044051170349, 0.8493540287017822, 0.8467700481414795, 0.845219612121582, 0.855555534362793, 0.8552971482276917, 0.8594315052032471, 0.8428940773010254, 0.8534883856773376, 0.8607234954833984, 0.8573643565177917, 0.8514211773872375, 0.85968995094299 ...
# 32/32 [==============================] - 1s 5ms/step

# %%
metrics_df.round(3)
# Out:
#     Client  Accuracy  Precision  Recall     F1  Sensitivity  Specificity  \
# 0        0     0.567      0.598   0.410  0.487        0.410        0.724
# 1        1     0.549      0.579   0.362  0.445        0.362        0.737
# 2        2     0.584      0.616   0.448  0.519        0.448        0.721
# 3        0     0.564      0.569   0.528  0.547        0.528        0.600
# 4        1     0.552      0.543   0.660  0.596        0.660        0.445
# 5        2     0.597      0.611   0.536  0.571        0.536        0.659
# 6        0     0.550      0.540   0.675  0.600        0.675        0.425
# 7        1     0.576      0.571   0.612  0.591        0.612        0.541
# 8        2     0.627      0.634   0.598  0.616        0.598        0.655
# 9        0     0.606      0.600   0.635  0.617        0.635        0.576
# 10       1     0.584      0.558   0.806  0.660        0.806        0.362
# 11       2     0.659      0.654   0.673  0.663        0.673        0.645
# 12       0     0.631      0.669   0.518  0.584        0.518        0.744
# 13       1     0.643      0.698   0.506  0.586        0.506        0.781
# 14       2     0.663      0.629   0.795  0.702        0.795        0.530
#
#     Kappa
# 0   0.134
# 1   0.099
# 2   0.169
# 3   0.127
# 4   0.105
# 5   0.195
# 6   0.101
# 7   0.153
# 8   0.253
# 9   0.211
# 10  0.168
# 11  0.317
# 12  0.261
# 13  0.287
# 14  0.325

# %%
metrics_df.round(4).to_csv('/content/drive/MyDrive/EEG Signal /results/FLresults/Frequency Domain/Delta_CNN_LSTM.csv', index = False)

# %% [markdown]
# # Draw Plot

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
import os

# Function to read CSV logs and extract accuracy and validation accuracy
def read_logs(log_dir, num_clients, local_epochs):
    dataframes = []
    for epoch in range(local_epochs):
        for client in range(num_clients):
            log_file = os.path.join(log_dir, f'training_log_epoch_{epoch}_client_{client}.csv')
            if os.path.exists(log_file):
                df = pd.read_csv(log_file, sep=';')
                df['epoch_number'] = epoch
                df['client_number'] = client
                dataframes.append(df)
            else:
                print(f"Log file not found: {log_file}")

    return pd.concat(dataframes) if dataframes else pd.DataFrame()

# Function to plot the training and validation accuracy
def plot_accuracy(all_metrics_df, unique_epochs, output_dir):
    # Set the Seaborn style
    sns.set(style="whitegrid")

    # Create subplots for each epoch
    fig, axes = plt.subplots(2, len(unique_epochs), figsize=(len(unique_epochs) * 3, 4.5), sharex=True)

    # Set the color palette
    palette = sns.color_palette("Set1", n_colors=all_metrics_df['client_number'].nunique())

    # Store the lines and labels for the legend
    lines = []
    labels = []

    # Iterate through each epoch and plot the training and validation accuracy
    for i, epoch in enumerate(unique_epochs):
        epoch_df = all_metrics_df[all_metrics_df['epoch_number'] == epoch]
        for j, client in enumerate(epoch_df['client_number'].unique()):
            client_df = epoch_df[epoch_df['client_number'] == client].dropna(subset=['accuracy', 'val_accuracy'])
            if not client_df.empty:
                line, = axes[0, i].plot(client_df.index, client_df['accuracy'], label=f'Client {client}', alpha=0.6, color=palette[j], linewidth=2.0)
                axes[1, i].plot(client_df.index, client_df['val_accuracy'], label=f'Client {client}', alpha=0.6, color=palette[j], linewidth=2.0)

                if i == 0:
                    lines.append(line)
                    labels.append(f'Client {client}')

        axes[0, i].set_title(f'Epoch {epoch}', fontsize=12, fontweight='bold')
        axes[0, i].set_xlim(0, 100)  # Ensure x-axis covers exactly 100 steps
        axes[1, i].set_xlim(0, 100)  # Ensure x-axis covers exactly 100 steps
        axes[1, i].set_xlabel('Steps', fontsize=10, fontweight='bold')
        axes[0, i].grid(True)
        axes[1, i].grid(True)
        axes[0, i].tick_params(axis='both', which='major', labelsize=10)
        axes[1, i].tick_params(axis='both', which='major', labelsize=10)

    # Add a single legend for the entire figure
    fig.legend(lines, labels, loc='upper center', bbox_to_anchor=(0.5, 1.0), ncol=len(labels), fontsize=10, frameon=True)

    # Add row labels
    fig.text(0.04, 0.75, 'Training Accuracy', ha='center', va='center', rotation='vertical', fontsize=12, fontweight='bold')
    fig.text(0.04, 0.25, 'Validation Accuracy', ha='center', va='center', rotation='vertical', fontsize=12, fontweight='bold')

    plt.tight_layout(rect=[0.05, 0, 1, 0.95])
    plt.subplots_adjust(hspace=0.2, top=0.88)  # Add some space between the rows and reduce space between the legend and plot

    # Save the figure in high DPI PNG and PDF
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    fig.savefig(os.path.join(output_dir, 'accuracy_plot.png'), dpi=300, format='png')
    fig.savefig(os.path.join(output_dir, 'accuracy_plot.pdf'), dpi=300, format='pdf')

    plt.show()

# Directory where CSV logs are saved
log_dir = '/content/drive/MyDrive/EEG Signal /Epileptic seizure/Saved model/Frequency_domain/Delta'

# Output directory for saving plots
output_dir = '/content/drive/MyDrive/EEG Signal /Epileptic seizure/Saved model/Frequency_domain/Delta/plots'

# Number of clients and local epochs
num_clients = 3
local_epochs = 5

# Read logs and generate the dataframe
all_metrics_df = read_logs(log_dir, num_clients, local_epochs)

# Get unique epochs from the dataframe
unique_epochs = sorted(all_metrics_df['epoch_number'].unique())

# Plot the accuracy
plot_accuracy(all_metrics_df, unique_epochs, output_dir)

# %% [markdown]
# # CNN

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split,KFold,StratifiedKFold
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, cohen_kappa_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, BatchNormalization, LSTM,Dropout, GRU
from tensorflow.keras.regularizers import l2
from tensorflow.keras.backend import clear_session
from keras.optimizers import RMSprop, Adam
# from wandb.keras import WandbCallback

class FederatedData:
    def __init__(self, data_path, num_clients, scaler_type='MinMax', k_folds=5, stratified=False):
        self.data_path = data_path
        self.num_clients = num_clients
        self.scaler_type = scaler_type
        self.k_folds = k_folds
        self.stratified = stratified
        self.partitions = []  # Initialize partitions attribute
        self.load_data()
        self.scale_data()
        self.create_partitions()

    def load_data(self):
        try:
            data = np.load(self.data_path, allow_pickle= True)
            self.X = np.moveaxis(data['X'], 1, 2)  # Move axis here
            self.Y = data['Y']
        except KeyError as e:
            raise ValueError(f"Missing expected data field: {e}")
        except FileNotFoundError as e:
            raise ValueError(f"Data file not found: {e}")

    def scale_data(self):
        # Reshape data to 2D array for scaling
        X_reshaped = self.X.reshape(-1, self.X.shape[-1])

        # Select scaler based on input
        if self.scaler_type == 'Standard':
            scaler = StandardScaler()
        elif self.scaler_type == 'MinMax':
            scaler = MinMaxScaler(feature_range=(0, 1))
        else:
            raise ValueError("Unsupported scaler type. Choose either 'Standard' or 'MinMax'.")

        # Fit and transform the data
        scaled_data_reshaped = scaler.fit_transform(X_reshaped)

        # Reshape back to original shape
        X = scaled_data_reshaped.reshape(self.X.shape)
        np.moveaxis(X, 1, 2)
        self.X = X

    def create_partitions(self):
        if self.stratified:
            kf = StratifiedKFold(n_splits=self.k_folds, shuffle=True, random_state=42)
        else:
            kf = KFold(n_splits=self.k_folds, shuffle=True, random_state=42)

        for train_index, test_index in kf.split(self.X, self.Y):
            X_train, X_test = self.X[train_index], self.X[test_index]
            Y_train, Y_test = self.Y[train_index], self.Y[test_index]
            self.partitions.append((X_train, Y_train, X_test, Y_test))
            print(f"Train shape: {X_train.shape}, Test shape: {X_test.shape}")

    def get_training_and_validation_data(self, client_idx):
        if client_idx < 0 or client_idx >= len(self.partitions):
            raise ValueError(f"Invalid client index. Must be between 0 and {len(self.partitions) - 1}.")

        partition_X_train, partition_Y_train, partition_X_test, partition_Y_test = self.partitions[client_idx]
        X_train, X_val, Y_train, Y_val = train_test_split(partition_X_train, partition_Y_train, test_size=0.2, random_state=42)
        return X_train, X_val, Y_train, Y_val, partition_X_test, partition_Y_test

    def get_testing_data(self, client_idx):
        if client_idx < 0 or client_idx >= len(self.partitions):
            raise ValueError(f"Invalid client index. Must be between 0 and {len(self.partitions) - 1}.")

        _, _, partition_X_test, partition_Y_test = self.partitions[client_idx]
        return partition_X_test, partition_Y_test

def build_sequential_model(input_shape):
    clear_session()
    model = Sequential()

    model.add(Conv1D(256, 3, strides=1, activation='relu', padding="same", input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(2, padding="same"))
    model.add(Conv1D(256, 3, strides=1, activation='relu', padding="same"))
    model.add(MaxPooling1D(2, padding="same"))
    model.add(Conv1D(512, 3, strides=1, activation='relu', padding="same"))
    model.add(MaxPooling1D(2, padding="same"))
    model.add(Conv1D(filters=1024, kernel_size=3, strides=1, activation='relu'))
    # model.add(Dropout(0.5))
    # model.add(LSTM(256, return_sequences=True))
    # model.add(LSTM(256, return_sequences=True))
        # GRU layers
    # model.add(GRU(256, return_sequences=True))
    # model.add(GRU(128, return_sequences=False))

    model.add(Flatten())
    # model.add(Dense(1024, activation='relu'))
    # model.add(Dense(512, activation='relu'))
    model.add(Dense(512, activation='relu'))
    model.add(Dense(256, activation='relu'))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))

    opt = Adam(learning_rate=0.00009, beta_1=0.9, beta_2=0.999, epsilon=1e-08)
    model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
    model.summary()
    return model

def compute_metrics(y_true, y_pred):
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred)
    kappa = cohen_kappa_score(y_true, y_pred)

    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
    specificity = tn / (tn + fp)
    sensitivity = recall

    return accuracy, precision, recall, f1, sensitivity, specificity, kappa

def federated_learning(data_path):
    federated_data = FederatedData(data_path, num_clients=3, scaler_type='MinMax')
    federated_data.create_partitions()

    # Get the input shape from the data
    input_shape = federated_data.X.shape[1:]
    global_model = build_sequential_model(input_shape)

    num_clients = 3
    local_epochs = 5
    global_optimizer = Adam(learning_rate=0.00009, beta_1=0.9, beta_2=0.999, epsilon=1e-08)

    # Initialize m and v for Adam optimizer
    m = [np.zeros_like(w) for w in global_model.get_weights()]
    v = [np.zeros_like(w) for w in global_model.get_weights()]
    beta1 = 0.9
    beta2 = 0.999
    epsilon = 1e-7
    t = 0

    client_data = []
    for client_idx in range(num_clients):
        x_train, x_val, y_train, y_val, x_test, y_test = federated_data.get_training_and_validation_data(client_idx)
        client_data.append((x_train, x_val, y_train, y_val, x_test, y_test))

    metrics_list = []

    for epoch in range(local_epochs):
        client_models = []

        for client in range(num_clients):
            x_train, x_val, y_train, y_val, x_test, y_test = client_data[client]
            client_model = build_sequential_model(input_shape)
            client_model.set_weights(global_model.get_weights())  # Initialize with global weights
            opt = Adam(learning_rate=0.000009, beta_1=0.9, beta_2=0.999, epsilon=1e-08)
            client_model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
            history = client_model.fit(x_train, y_train, epochs=100, batch_size=128, validation_data=(x_val, y_val), callbacks=[])
            client_models.append(client_model)

            print(history.history)

            # Evaluate client model
            y_pred = (client_model.predict(x_test) > 0.5).astype("int32")
            accuracy, precision, recall, f1, sensitivity, specificity, kappa = compute_metrics(y_test, y_pred)
            metrics_list.append({
                'Client': client,
                'Accuracy': accuracy,
                'Precision': precision,
                'Recall': recall,
                'F1': f1,
                'Sensitivity': sensitivity,
                'Specificity': specificity,
                'Kappa': kappa
            })

        global_weights = global_model.get_weights()
        layer_start_idx = 0
        for layer in global_model.layers:
            layer_weights = []
            layer_biases = []
            num_params = len(layer.get_weights())
            for i in range(num_clients):
                layer_params = client_models[i].get_weights()[layer_start_idx:layer_start_idx + num_params]
                if num_params > 0:
                    layer_weights.append(layer_params[0])
                if num_params > 1:
                    layer_biases.append(layer_params[1])

            if len(layer_weights) > 0:
                averaged_layer_weights = np.mean(layer_weights, axis=0)
                if averaged_layer_weights.shape == global_weights[layer_start_idx].shape:
                    global_weights[layer_start_idx] = averaged_layer_weights
                else:
                    print(f"Warning: Shape mismatch for weights at layer {layer.name}, expected {global_weights[layer_start_idx].shape} but got {averaged_layer_weights.shape}")
            if len(layer_biases) > 0:
                averaged_layer_biases = np.mean(layer_biases, axis=0)
                if averaged_layer_biases.shape == global_weights[layer_start_idx + 1].shape:
                    global_weights[layer_start_idx + 1] = averaged_layer_biases
                else:
                    print(f"Warning: Shape mismatch for biases at layer {layer.name}, expected {global_weights[layer_start_idx + 1].shape} but got {averaged_layer_biases.shape}")

            layer_start_idx += num_params

        # Apply FedOpt (Adam) update to global weights
        t += 1
        for i in range(len(global_weights)):
            g_t = global_weights[i] - global_model.get_weights()[i]  # Gradient
            m[i] = beta1 * m[i] + (1 - beta1) * g_t
            v[i] = beta2 * v[i] + (1 - beta2) * (g_t ** 2)
            m_hat = m[i] / (1 - beta1 ** t)
            v_hat = v[i] / (1 - beta2 ** t)
            global_weights[i] -= global_optimizer.learning_rate * m_hat / (np.sqrt(v_hat) + epsilon)

        global_model.set_weights(global_weights)

    metrics_df = pd.DataFrame(metrics_list)
    return global_model, metrics_df
# Example usage
# data_path = 'path/to/your/data.npz'
# global_model, metrics_df = federated_learning(data_path)
# print(metrics_df)

# %%
global_model_CNN, metrics_df_CNN = federated_learning(Theta_data)

# %%
metrics_df_CNN.round(3)

# %%
metrics_df_CNN.round(4).to_csv('/content/drive/MyDrive/EEG Signal /results/FLresults/Time Domain/Delta_time_CNN.csv', index = False)
